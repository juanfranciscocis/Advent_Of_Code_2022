# %%
with open('day2.txt', 'r') as file:
    data = file.read()

data = data.split("\n")
data
# Out:
# ['B X',
#  'A Z',
#  'A Y',
#  'B X',
#  'C Z',
#  'B Y',
#  'B X',
#  'C X',
#  'A Y',
#  'B Y',
#  'B Y',
#  'C Y',
#  'B Y',
#  'C Y',
#  'B X',
#  'A Z',
#  'C Y',
#  'B Z',
#  'C X',
#  'A Y',
#  'B Y',
#  'B Y',
#  'B Y',
#  'B Y',
#  'B X',
#  'B Y',
#  'C Y',
#  'B Y',
#  'B Y',
#  'B Y',
#  'A Y',
#  'B X',
#  'A Y',
#  'A Y',
#  'B X',
#  'B Z',
#  'B Y',
#  'C Y',
#  'A Y',
#  'A Z',
#  'C Y',
#  'A Z',
#  'C Z',
#  'C Y',
#  'B Z',
#  'C X',
#  'A Z',
#  'C Y',
#  'B X',
#  'B X',
#  'C Z',
#  'C Y',
#  'B Y',
#  'A X',
#  'C Z',
#  'B Y',
#  'B X',
#  'A Z',
#  'B Z',
#  'C Y',
#  'C Z',
#  'B X',
#  'B Y',
#  'B Y',
#  'C Y',
#  'B Y',
#  'B Y',
#  'C Y',
#  'B Z',
#  'A Y',
#  'B Y',
#  'C Y',
#  'B Y',
#  'B Y',
#  'B Y',
#  'C Y',
#  'B X',
#  'C X',
#  'C Y',
#  'B X',
#  'B X',
#  'C X',
#  'B Y',
#  'C Z',
#  'B Y',
#  'B Y',
#  'B Y',
#  'C Y',
#  'B X',
#  'A Z',
#  'C Y',
#  'A Z',
#  'B X',
#  'B X',
#  'A Y',
#  'C X',
#  'B Z',
#  'B Y',
#  'B X',
#  'C X',
# ...

# %%
win  = 6
loose = 0
draw = 3

rock = 1
paper = 2
scissors = 3

# %%
# Appreciative of your help yesterday, one Elf gives you an encrypted strategy guide (your puzzle input) that they say will be sure to help you win. "The first column is what your opponent is going to play: A for Rock, B for Paper, and C for Scissors. The second column--" Suddenly, the Elf is called away to help with someone's tent.

# The second column, you reason, must be what you should play in response: X for Rock, Y for Paper, and Z for Scissors. Winning every time would be suspicious, so the responses must have been carefully chosen.

# %%
pairs = []
for i in data:
    pairs.append(i.split(" "))

# %%
pairs
# Out:
# [['B', 'X'],
#  ['A', 'Z'],
#  ['A', 'Y'],
#  ['B', 'X'],
#  ['C', 'Z'],
#  ['B', 'Y'],
#  ['B', 'X'],
#  ['C', 'X'],
#  ['A', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['B', 'X'],
#  ['A', 'Z'],
#  ['C', 'Y'],
#  ['B', 'Z'],
#  ['C', 'X'],
#  ['A', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['B', 'X'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['A', 'Y'],
#  ['B', 'X'],
#  ['A', 'Y'],
#  ['A', 'Y'],
#  ['B', 'X'],
#  ['B', 'Z'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['A', 'Y'],
#  ['A', 'Z'],
#  ['C', 'Y'],
#  ['A', 'Z'],
#  ['C', 'Z'],
#  ['C', 'Y'],
#  ['B', 'Z'],
#  ['C', 'X'],
#  ['A', 'Z'],
#  ['C', 'Y'],
#  ['B', 'X'],
#  ['B', 'X'],
#  ['C', 'Z'],
#  ['C', 'Y'],
#  ['B', 'Y'],
#  ['A', 'X'],
#  ['C', 'Z'],
#  ['B', 'Y'],
#  ['B', 'X'],
#  ['A', 'Z'],
#  ['B', 'Z'],
#  ['C', 'Y'],
#  ['C', 'Z'],
#  ['B', 'X'],
#  ['B', 'Y'],
#  ['B', 'Y'],
#  ['C', 'Y'],
#  ['B', 'Y'],
# ...

# %%
scores = []
for j in pairs:
    if(j[0] == "A" and j[1]=="X"):
        scores.append((draw,rock))
    elif(j[0] == "A" and j[1]=="Y"):
        scores.append((win,paper))
    elif(j[0] == "A" and j[1]=="Z"):
        scores.append((loose,scissors))
    elif(j[0] == "B" and j[1]=="X"):
        scores.append((loose,rock))
    elif(j[0] == "B" and j[1]=="Y"):
        scores.append((draw,paper))
    elif(j[0] == "B" and j[1]=="Z"):
        scores.append((win,scissors))
    elif(j[0] == "C" and j[1]=="X"):
        scores.append((win,rock))
    elif(j[0] == "C" and j[1]=="Y"):
        scores.append((loose,paper))
    elif(j[0] == "C" and j[1]=="Z"):
        scores.append((draw,scissors))

# %%
scores
# Out:
# [(0, 1),
#  (0, 3),
#  (6, 2),
#  (0, 1),
#  (3, 3),
#  (3, 2),
#  (0, 1),
#  (6, 1),
#  (6, 2),
#  (3, 2),
#  (3, 2),
#  (0, 2),
#  (3, 2),
#  (0, 2),
#  (0, 1),
#  (0, 3),
#  (0, 2),
#  (6, 3),
#  (6, 1),
#  (6, 2),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (0, 1),
#  (3, 2),
#  (0, 2),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (6, 2),
#  (0, 1),
#  (6, 2),
#  (6, 2),
#  (0, 1),
#  (6, 3),
#  (3, 2),
#  (0, 2),
#  (6, 2),
#  (0, 3),
#  (0, 2),
#  (0, 3),
#  (3, 3),
#  (0, 2),
#  (6, 3),
#  (6, 1),
#  (0, 3),
#  (0, 2),
#  (0, 1),
#  (0, 1),
#  (3, 3),
#  (0, 2),
#  (3, 2),
#  (3, 1),
#  (3, 3),
#  (3, 2),
#  (0, 1),
#  (0, 3),
#  (6, 3),
#  (0, 2),
#  (3, 3),
#  (0, 1),
#  (3, 2),
#  (3, 2),
#  (0, 2),
#  (3, 2),
#  (3, 2),
#  (0, 2),
#  (6, 3),
#  (6, 2),
#  (3, 2),
#  (0, 2),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (0, 2),
#  (0, 1),
#  (6, 1),
#  (0, 2),
#  (0, 1),
#  (0, 1),
#  (6, 1),
#  (3, 2),
#  (3, 3),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (0, 2),
#  (0, 1),
#  (0, 3),
# ...

# %%
sumOfScores = 0
for k in scores:
    sumOfScores += k[0] + k[1]

# %%
sumOfScores
# Out:
# 10994

# %%
scores = []
for j in pairs:
    if(j[0] == "A" and j[1]=="X"):
        scores.append((loose,scissors))
    elif(j[0] == "A" and j[1]=="Y"):
        scores.append((draw,rock))
    elif(j[0] == "A" and j[1]=="Z"):
        scores.append((win,paper))
    elif(j[0] == "B" and j[1]=="X"):
        scores.append((loose,rock))
    elif(j[0] == "B" and j[1]=="Y"):
        scores.append((draw,paper))
    elif(j[0] == "B" and j[1]=="Z"):
        scores.append((win,scissors))
    elif(j[0] == "C" and j[1]=="X"):
        scores.append((loose,paper))
    elif(j[0] == "C" and j[1]=="Y"):
        scores.append((draw,scissors))
    elif(j[0] == "C" and j[1]=="Z"):
        scores.append((win,rock))

# %%
scores
# Out:
# [(0, 1),
#  (6, 2),
#  (3, 1),
#  (0, 1),
#  (6, 1),
#  (3, 2),
#  (0, 1),
#  (0, 2),
#  (3, 1),
#  (3, 2),
#  (3, 2),
#  (3, 3),
#  (3, 2),
#  (3, 3),
#  (0, 1),
#  (6, 2),
#  (3, 3),
#  (6, 3),
#  (0, 2),
#  (3, 1),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (0, 1),
#  (3, 2),
#  (3, 3),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (3, 1),
#  (0, 1),
#  (3, 1),
#  (3, 1),
#  (0, 1),
#  (6, 3),
#  (3, 2),
#  (3, 3),
#  (3, 1),
#  (6, 2),
#  (3, 3),
#  (6, 2),
#  (6, 1),
#  (3, 3),
#  (6, 3),
#  (0, 2),
#  (6, 2),
#  (3, 3),
#  (0, 1),
#  (0, 1),
#  (6, 1),
#  (3, 3),
#  (3, 2),
#  (0, 3),
#  (6, 1),
#  (3, 2),
#  (0, 1),
#  (6, 2),
#  (6, 3),
#  (3, 3),
#  (6, 1),
#  (0, 1),
#  (3, 2),
#  (3, 2),
#  (3, 3),
#  (3, 2),
#  (3, 2),
#  (3, 3),
#  (6, 3),
#  (3, 1),
#  (3, 2),
#  (3, 3),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (3, 3),
#  (0, 1),
#  (0, 2),
#  (3, 3),
#  (0, 1),
#  (0, 1),
#  (0, 2),
#  (3, 2),
#  (6, 1),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (3, 3),
#  (0, 1),
#  (6, 2),
# ...

# %%
sumOfScores = 0
for k in scores:
    sumOfScores += k[0] + k[1]

# %%
sumOfScores
# Out:
# 12526
